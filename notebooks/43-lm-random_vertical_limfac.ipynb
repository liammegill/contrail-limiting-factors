# %% [markdown]
# # Vertical limiting factors analysis
#
# _Dataset:_ Supplementary data for Megill and Grewe (2025): "Investigating the limiting aircraft design-dependent and environmental factors of persistent contrail formation".
#
# _Authors:_
#
# - Liam Megill (1, 2), https://orcid.org/0000-0002-4199-6962
# - Volker Grewe (1, 2), https://orcid.org/0000-0002-8012-6783
#
# _Affiliation (1)_: Deutsches Zentrum für Luft- und Raumfahrt (DLR), Institut für Physik der Atmosphäre, Oberpfaffenhofen, Germany
#
# _Affiliation (2)_: Delft University of Technology (TU Delft), Faculty of Aerospace Engineering, Section Aircraft Noise and Climate Effects (ANCE), Delft, The Netherlands
#
# _Corresponding author_: Liam Megill, liam.megill@dlr.de
#
# _doi_: https://doi.org/10.5194/egusphere-2024-3398
#
# ---
#
#
# ### Summary
# This notebook analyses the vertical limiting factors of persistent contrail formation using ERA5 data. It randomly generates hours within the 2010 decade, performs the analysis between `starting_season` and `ending_season` and saves the results.
#
# ### Inputs
# - `limfac` module: https://github.com/liammegill/contrail-limiting-factors
# - `data/aircraft_specs_v3.nc`: Aircraft specifications created with `02-lm-create_aircraft_specs.ipynb`.
# - `data/processed/limfac/vertical_neighbors_grib.pickle`: Vertical grid cell neighbors
# - `data/processed/limfac/areas_grib.pickle`: Grid cell areas
# - ERA5 GRIB data: If not performing the study on DKRZ Levante, the ERA5 GRIB data needs to be saved locally. We recommend placing the ERA5 files in `data/raw/`: ambient temperature files in a subfolder `130` and relative humidity files in a subfolder `157`. The path to the folder containing the ERA5 data needs to be provided to `lf.load_era5_dataset` using the optional variable `dir_path`. If necessary, the `lf.load_era5_dataset` function may have to be adapted, which can be found in `configure_input.py`.
#
# ### Outputs
# - `data/processed/limfac/AC*/vert_limfac_{ac_id}_r1S_{season_year}_ERA5_GRIB_{cor_savename_ext}.nc`: Limiting factors results for aircraft `ac_id`, season-year (e.g. 2010 DJF) `season_year` and RHi enhancement `cor_savename_ext`. The results are saved into a subfolder `AC*` which corresponds to `ac_id`.
#
# ---
#
# ### Copyright
#
# Copyright © 2025 Liam Megill
#
# Licensed under the Apache License, Version 2.0 (the "License"); you may not use this file except in compliance with the License. You may obtain a copy of the License at http://www.apache.org/licenses/LICENSE-2.0. Unless required by applicable law or agreed to in writing, software distributed under the License is distributed on an "AS IS" BASIS, WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied. See the License for the specific language governing permissions and limitations under the License.

# %% [markdown]
# To start, set the top-level directory path `project_dir`. Then, select the starting and ending seasons and the aircraft design to be analysed. In the linked paper, a `random_seed` of 42 and `num_h_per_s` (number of hours selected per season) of 2190. The RHi enhancement ("correction") can be selected by modifying variables `rhi_cor` (multiplier) and `cor_savename_ext` (extension that gets added to the end of the save name).

# %%
# load modules
import warnings
import multiprocessing
import datetime
import pickle
import sys
import glob
import os
import numpy as np
import xarray as xr
import pandas as pd
import cf2cdm
from collections import defaultdict
from functools import partial
from tqdm import tqdm

# define directories and import limfac module
project_dir = ""  # set top-level directory path
processed_data_dir = project_dir + "data/processed/limfac/"
sys.path.append(project_dir)
import limfac as lf

# options
random_seed = 42  # seed for np.random
num_h_per_s = 2190  # total number of random hours per season (DJF, MAM, JJA, SON)
starting_season = "2010DJF"
ending_season = "2019SON"  # inclusive!

# load aircraft
ac_id = "AC1"  # choice of aircraft - matches ac_id in ac dataset
ac = xr.load_dataset(project_dir+"data/aircraft_specs_v3.nc").sel(id=ac_id)

# multiprocessing options
req_mem_single_day = 2  # GB - memory required for each worker
available_mem = 30  # GB - change to match available memory in partition
max_workers = available_mem // req_mem_single_day

# correction
test_savename_ext = False  # this adds the "test" flag to the savename
rhi_cor = 1.0  # correction to RHi
cor_savename_ext = "uncor"  # this gets added to the end of the savename

# %% [markdown]
# The first step is to select the random hours within the 2010 decade that will be analysed.

# %%
# calculate random hours
rnd_hrs = lf.select_random_hours(num_h_per_s, seed=random_seed)
rnd_hrs_flat = np.concatenate(rnd_hrs)
rnd_hrs_flat.sort()
rnd_hrs_flat = pd.to_datetime(rnd_hrs_flat)

# associate random hours to season-years
rnd_hrs_per_sy = defaultdict(list)
for rnd_hr in rnd_hrs_flat:
    season_year = lf.get_season_year(rnd_hr)
    rnd_hrs_per_sy[season_year].append(rnd_hr)

# create full list of season-years
all_sy = lf.generate_season_years(2010, 2019)
start_sy_idx = all_sy.index(starting_season)
end_sy_idx = all_sy.index(ending_season)
season_years = all_sy[start_sy_idx:end_sy_idx+1]

# %% [markdown]
# Next, we load `vert_neighbors` and `areas`, which are required by the main function.

# %%
# load neighbors, areas
with open(processed_data_dir+"vertical_neighbors_grib.pickle", "rb") as f:
    vert_neighbors = pickle.load(f)
with open(processed_data_dir+"areas_grib.pickle", "rb") as f:
    areas = pickle.load(f)

# %% [markdown]
# We define the `process_day` function, which is used by each worker to calculate the results for a single day.

# %%
def process_day(date, ac, rnd_hrs_sy, rhi_cor):
    # assumes neighbors, perimeters from outer loop

    # get hours on date
    date_str = date.strftime("%Y-%m-%d")
    hrs = rnd_hrs_sy[rnd_hrs_sy.date == date]

    # load data and calculate results
    dsg = lf.load_era5_dataset(date_str)
    dsg = dsg.sel(time=hrs, drop=False)
    res = lf.calc_limfacs(dsg, ac, "v", vert_neighbors, areas, rhi_cor)
    return res

# %% [markdown]
# Finally, we perform the analysis. For each `season_year`, we initialise a dataset `ds_sum` of zeros and add the results of each day to it. We use `multiprocessing.Pool` to process each unique day in parallel and keep track of progress using a progress bar from the `tqdm` module. Once the results of all unique days have been added to `ds_sum`, we normalise the results using the number of random hours within that season year (`rnd_hrs_sy`) and save the resulting dataset `ds_tot` to file.

# %%
for season_year in season_years:
    # get random hours and unique days within season-year
    rnd_hrs_sy = pd.to_datetime(rnd_hrs_per_sy[season_year])
    unique_days = pd.Series(rnd_hrs_sy).dt.date.unique()

    # initialise ds_sum
    ds_ex = lf.load_era5_dataset(unique_days[0])
    ds_sum = xr.Dataset(
        {"limfac_tot": (["level", "values"], np.zeros((ds_ex.level.size, ds_ex.latitude.size))),
         "limfac_frm": (["level", "values"], np.zeros((ds_ex.level.size, ds_ex.latitude.size))),
         "limfac_frz": (["level", "values"], np.zeros((ds_ex.level.size, ds_ex.latitude.size))),
         "limfac_per": (["level", "values"], np.zeros((ds_ex.level.size, ds_ex.latitude.size))),
         "limfac_wss": (["level", "values"], np.zeros((ds_ex.level.size, ds_ex.latitude.size))),
         "ppcf": (["level", "values"], np.zeros((ds_ex.level.size, ds_ex.latitude.size)))
        },
        coords={"level": ds_ex.level.data,
                "latitude": ("values", ds_ex.latitude.data),
                "longitude": ("values", ds_ex.longitude.data)}
    )
    ds_ex = None  # reduce memory usage

    # use multiprocessing to process days in parallel
    with multiprocessing.Pool(processes=max_workers) as pool:
        partial_func = partial(process_day, ac=ac, rnd_hrs_sy=rnd_hrs_sy, rhi_cor=rhi_cor)
        with tqdm(total=len(unique_days), desc=f"Processing {ac_id} {cor_savename_ext} {season_year}", unit="day") as pbar:
            for day_res in pool.imap_unordered(partial_func, unique_days):
                ds_sum += day_res
                pbar.update(1)

    # save dataset
    ds_tot = ds_sum / len(rnd_hrs_sy)
    ds_tot = ds_tot.assign(n_time=len(rnd_hrs_sy))
    ds_tot.attrs.update({"author": "Liam Megill",
                         "institution": "Deutsches Zentrum für Luft- und Raumfahrt, Institute of Atmospheric Physics",
                         "description": "Seasonal vertical contrail limiting factors, calculated using random hours within the 2010 decade of ERA5 GRIB data stored on DKRZ Levante",
                         "seed": random_seed,
                         "aircraft_id": ac_id,
                         "timespan": f"{season_year}",
                         "n_time": len(rnd_hrs_sy),
                         "created": "{} CET".format(datetime.datetime.today().strftime("%Y-%m-%d %H:%M:%S")),
                         "corrections": cor_savename_ext})

    savename = f"{processed_data_dir}{ac_id}/{'test_' if test_savename_ext else ''}vert_limfac_{ac_id}_r1S_{season_year}_ERA5_GRIB_{cor_savename_ext}.nc"
    ds_tot.to_netcdf(savename)
    ds_tot.close()
    ds_sum.close()
